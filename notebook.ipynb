# %%
import pandas as pd
from sqlalchemy import create_engine
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
starbucks_california_csv = "Resources/starbucks_california.csv"
starbucks_cali_df = pd.read_csv(starbucks_california_csv)
starbucks_cali_df.head()
# Out:
#       ID                          Name Ownership Type    Phone Number  \
# 0   9128       100 West Portal/Vicente  Company Owned  (415) 664-8370
# 1  14672       10th & Hwy 14, Palmdale  Company Owned    661-266-2314
# 2   8147      10th & Market, San Diego  Company Owned    619-696-3750
# 3  15457  11th & Corral Hollow - Tracy  Company Owned    209-830-1348
# 4  10036     11th & Grand, Los Angeles  Company Owned      2137491751
#
#                                              Address  \
# 0  100 West Portal, 941271306  San Francisco Coun...
# 1  39904 10th Street West, 935513003  Los Angeles...
# 2  1011 Market Street, 921017233  San Diego Count...
# 3  1857 W. 11th Street, 953763727  San Joaquin Co...
# 4  1111 South Grand Avenue, 900152176  Los Angele...
#
#                                    City                County        Zip  \
# 0  San Francisco - San Francisco County  San Francisco County  941271306
# 1         Palmdale - Los Angeles County    Los Angeles County  935513003
# ...

# %%
starbucks_directory_csv = "Resources/directory_v2.csv"
starbucks_directory_df = pd.read_csv(starbucks_directory_csv)
starbucks_directory_df.head()
# Out:
#        Brand  Store Number               Store Name Ownership Type  \
# 0  Starbucks  10429-100710       Palmdale & Hwy 395  Company Owned
# 1  Starbucks       635-352    Kanan & Thousand Oaks  Company Owned
# 2  Starbucks   74510-27669  Vons-Agoura Hills #2001       Licensed
# 3  Starbucks  29839-255026    Target Anaheim T-0677       Licensed
# 4  Starbucks  23463-230284   Safeway - Alameda 3281       Licensed
#
#                  Street Address          City State/Province Country  \
# 0              14136 US Hwy 395      Adelanto             CA      US
# 1               5827 Kanan Road        Agoura             CA      US
# 2                5671 Kanan Rd.  Agoura Hills             CA      US
# 3  8148 E SANTA ANA CANYON ROAD       AHAHEIM             CA      US
# 4               2600 5th Street       Alameda             CA      US
#
#     Postcode    Phone Number                       Timezone  Longitude  \
# 0  923016700    760-530-9252  GMT-08:00 America/Los_Angeles    -117.40
# ...

# %%
#starbucks_cali_df['Phone Number'] = starbucks_cali_df['Phone Number'].map(lambda x: x.lstrip(')(-').str.rstrip('aAbBcC'))
starbucks_cali_df['Phone Number'] = starbucks_cali_df['Phone Number'].str.replace('-', '')
starbucks_cali_df['Phone Number'] = starbucks_cali_df['Phone Number'].str.replace('(', '')
starbucks_cali_df['Phone Number'] = starbucks_cali_df['Phone Number'].str.replace(')', '')
starbucks_cali_df['Phone Number'] = starbucks_cali_df['Phone Number'].str.strip()

starbucks_cali_df
# Out:
#            ID                                 Name Ownership Type  \
# 0        9128              100 West Portal/Vicente  Company Owned
# 1       14672              10th & Hwy 14, Palmdale  Company Owned
# 2        8147             10th & Market, San Diego  Company Owned
# 3       15457         11th & Corral Hollow - Tracy  Company Owned
# 4       10036            11th & Grand, Los Angeles  Company Owned
# 5       16871               11th & Lacey - Hanford  Company Owned
# 6       16824                       120 4th Street  Company Owned
# 7      116312            120 W Calaveras- Milpitas  Company Owned
# 8       18456          1228 Broadway - Placerville  Company Owned
# 9        9169                   123 Mission Street  Company Owned
# 10      11581                   1231 Market Street  Company Owned
# 11      14680           12th & Centennial, Hanford  Company Owned
# 12      17033  12th & Hill, Los Angeles(AT&T Bldg)  Company Owned
# ...

# %%
starbucks_cali_df.head()
# Out:
#       ID                          Name Ownership Type Phone Number  \
# 0   9128       100 West Portal/Vicente  Company Owned  415 6648370
# 1  14672       10th & Hwy 14, Palmdale  Company Owned   6612662314
# 2   8147      10th & Market, San Diego  Company Owned   6196963750
# 3  15457  11th & Corral Hollow - Tracy  Company Owned   2098301348
# 4  10036     11th & Grand, Los Angeles  Company Owned   2137491751
#
#                                              Address  \
# 0  100 West Portal, 941271306  San Francisco Coun...
# 1  39904 10th Street West, 935513003  Los Angeles...
# 2  1011 Market Street, 921017233  San Diego Count...
# 3  1857 W. 11th Street, 953763727  San Joaquin Co...
# 4  1111 South Grand Avenue, 900152176  Los Angele...
#
#                                    City                County        Zip  \
# 0  San Francisco - San Francisco County  San Francisco County  941271306
# 1         Palmdale - Los Angeles County    Los Angeles County  935513003
# ...
